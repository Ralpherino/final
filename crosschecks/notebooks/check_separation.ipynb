# %% [markdown]
# ## Loading the dataset for inclusive MC. magup/magdown

# %%
# %run load-rds-final-2012-23903000-rs.ipynb
# Out:
# Welcome to JupyROOT 6.28/00
# <style>.container { width:95% !important; }</style>
# Loaded rdf with 305828 enries

# %%
rdf.Count().GetValue()
# Out:
# 305828

# %% [markdown]
# ## Checking the Xc BKGCAT

# %%
df = pd.DataFrame(rdf.Cache(["B_Y_SEP"]).AsNumpy())

# %%
df.hist("B_Y_SEP", bins=100, range=[-20, 5])
plt.yscale("log")
