# %%
# Setting up the python/jupyter environment
import pandas as pd
import ROOT
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image
import tabulate

# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,10)
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# Welcome to JupyROOT 6.28/00
# <style>.container { width:95% !important; }</style>

# %%
from data import simple_load_inclusiveMC_df
import yaml

# Loading the template configuration
with open("../config/templates.yaml") as yf:
    templates_config = yaml.load(yf, Loader=yaml.SafeLoader)


df = simple_load_inclusiveMC_df()
# Out:
# ['root://eoslhcb.cern.ch//eos/lhcb/wg/semileptonic/RDsHad/AP/final/ap_post_process/validated/rds_final_2012_23903000_magdown_rs.root', 'root://eoslhcb.cern.ch//eos/lhcb/wg/semileptonic/RDsHad/AP/final/ap_post_process/validated/rds_final_2012_23903000_magup_rs.root']

# %%
df.shape
# Out:
# (233110, 41)

# %%
def mygroupby(d, groupbycols):
    g = d.groupby(groupbycols).size().reset_index(name='count').sort_values([ 'count'], ascending=False).reset_index(drop=True)
    g["Percentage"] = g.apply(lambda row: 100 * row["count"]/d.shape[0], axis=1)
    g["cumulative %"] = g["Percentage"].cumsum(axis = 0)
    return g

# %%
mygroupby(df, 'key')
# Out:
#                                                   key  count  Percentage  \
# 0              Xc_signal_Ypis_displaced_fromBs_fromDs  47066   20.190468
# 1              Xc_signal_Ypis_displaced_fromB0_fromDp  46669   20.020162
# 2      Xc_signal_Ypis_diffVertex_doubleCharm_OneFromB  35243   15.118614
# 3                                       Xc_background  20449    8.772253
# 4              Xc_signal_Ypis_displaced_fromBp_fromD0  18506    7.938741
# 5                  Xc_signal_Ypis_nomatch_doubleCharm  15667    6.720861
# 6              Xc_signal_Ypis_displaced_fromBs_fromDp  10747    4.610270
# 7    Xc_signal_Ypis_displaced_fromLambdab_fromLambdac   6433    2.759641
# 8              Xc_signal_Ypis_displaced_fromBp_fromDp   5843    2.506542
# 9               Xc_signal_Ypis_diffVertex_doubleCharm   4607    1.976320
# 10             Xc_signal_Ypis_displaced_fromB0_fromD0   3804    1.631848
# 11            Xc_signal_Ypis_displaced_fromBs_fromTau   3489    1.496718
# 12             Xc_signal_Ypis_diffVertex_CharmStrange   3373    1.446956
# 13             Xc_signal_Ypis_displaced_fromB0_fromDs   2108    0.904294
# 14     Xc_signal_Ypis_diffVertex_doubleCharm_TwoFromB   1298    0.556819
# 15                     Xc_signal_Ypis_B_vertex_fromBs   1149    0.492900
# 16             Xc_signal_Ypis_displaced_fromBs_fromD0   1005    0.431127
# 17     Xc_signal_Ypis_displaced_fromBs_fromDs_fromTau    985    0.422547
# 18                     Xc_signal_Ypis_diffAncestorYXc    917    0.393377
# 19                Xc_signal_Ypis_nomatch_charmStrange    874    0.374930
# 20                      Xc_signal_Ypis_nomatch_Prompt    703    0.301574
# 21             Xc_signal_Ypis_displaced_fromBp_fromDs    686    0.294282
# 22               Xc_signal_Ypis_diffVertex_SomeFromPV    474    0.203337
# 23        Xc_signal_Ypis_displaced_fromLambdab_fromDs    217    0.093089
# 24        Xc_signal_Ypis_displaced_fromLambdab_fromDp    147    0.063060
# 25                   Xc_signal_Ypis_displaced_fromXic     77    0.033032
# 26                 Xc_signal_Ypis_B_vertex_fromOtherB     71    0.030458
# 27                   Xc_signal_Ypis_diffVertex_signal     68    0.029171
# 28                 Xc_signal_Ypis_diffVertex_normlike     68    0.029171
# 29                    Xc_signal_Ypis_displaced_fromBs     67    0.028742
# 30                                                 NA     48    0.020591
# 31     Xc_signal_Ypis_displaced_fromB0_fromDs_fromTau     46    0.019733
# 32                     Xc_signal_Ypis_B_vertex_fromHc     43    0.018446
# 33                       Xc_signal_Ypis_nomatch_Other     42    0.018017
# 34     Xc_signal_Ypis_displaced_fromB0_fromDp_fromTau     39    0.016730
# 35        Xc_signal_Ypis_displaced_fromLambdab_fromD0     15    0.006435
# 36     Xc_signal_Ypis_displaced_fromBp_fromDs_fromTau     15    0.006435
# 37     Xc_signal_Ypis_displaced_fromBs_fromDp_fromTau     10    0.004290
# 38                        Xc_signal_Ypis_displaced_NA     10    0.004290
# 39  Xc_signal_Ypis_displaced_fromLambdab_fromDs_fr...      8    0.003432
# 40     Xc_signal_Ypis_displaced_fromBp_fromDp_fromTau      7    0.003003
# 41                 Xc_signal_Ypis_diffVertex_tauFromB      5    0.002145
# 42                    Xc_signal_Ypis_displaced_fromBp      4    0.001716
# 43        Xc_signal_Ypis_displaced_fromB0_fromLambdac      2    0.000858
# 44               Xc_signal_Ypis_displaced_fromLambdac      2    0.000858
# 45                    Xc_signal_Ypis_displaced_fromB0      2    0.000858
# 46        Xc_signal_Ypis_displaced_fromBs_fromLambdac      1    0.000429
# 47                    Xc_signal_Ypis_displaced_fromDs      1    0.000429
#
#     cumulative %
# 0      20.190468
# 1      40.210630
# 2      55.329244
# 3      64.101497
# 4      72.040239
# 5      78.761100
# 6      83.371370
# 7      86.131011
# 8      88.637553
# 9      90.613873
# 10     92.245721
# 11     93.742439
# 12     95.189396
# 13     96.093690
# 14     96.650508
# 15     97.143409
# 16     97.574536
# 17     97.997083
# 18     98.390459
# 19     98.765390
# 20     99.066964
# 21     99.361246
# 22     99.564583
# 23     99.657672
# 24     99.720733
# 25     99.753764
# 26     99.784222
# 27     99.813393
# 28     99.842564
# 29     99.871305
# 30     99.891897
# 31     99.911630
# 32     99.930076
# 33     99.948093
# 34     99.964823
# 35     99.971258
# 36     99.977693
# 37     99.981983
# 38     99.986273
# 39     99.989704
# 40     99.992707
# 41     99.994852
# 42     99.996568
# 43     99.997426
# 44     99.998284
# 45     99.999142
# 46     99.999571
# 47    100.000000

# %%
mygroupby(df.query('bdt_dc > 0.75'), 'key')
