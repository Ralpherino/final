# %% [markdown]
# # Optimizing hyperparameters with optuna

# %% [markdown]
# ### Loading the data from disk (as saved by Prepare-training-data)

# %%
import xgboost as xgb
import sklearn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import roc_curve, auc
from scipy.stats import ks_2samp
import optuna

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (10,5)
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
data = np.load("bdt_training_data.npz")
Xtrain_scaled = data['Xtrain_scaled']
ytrain = data['ytrain']
Xvalid_scaled = data['Xvalid_scaled']
yvalid = data['yvalid']
Xtest_scaled = data['Xtest_scaled']
ytest = data['ytest']
train_columns = data['train_columns']
print(f"Ratio bkg/sig:{ np.count_nonzero(ytrain == 0) / np.count_nonzero(ytrain)}")
# Out:
# Ratio bkg/sig:50.82315420188168

# %%
Xtrain_scaled.shape
# Out:
# (324983, 23)

# %%
Xvalid_scaled.shape
# Out:
# (162408, 23)

# %%
Xtest_scaled.shape
# Out:
# (162408, 23)

# %% [markdown]
#  # Utility methods

# %%
def get_bdt_reponse_similarity(clf, X_train, y_train, X_test, y_test):

    # Getting the BDT response
    train_sig = clf.predict_proba(X_train[y_train==1])[:,1]
    train_bkg = clf.predict_proba(X_train[y_train==0])[:,1]
    test_sig = clf.predict_proba(X_test[y_test==1])[:,1]
    test_bkg = clf.predict_proba(X_test[y_test==0])[:,1]
    
    ks_sig = ks_2samp(train_sig, test_sig, alternative='two-sided')
    ks_bkg = ks_2samp(train_bkg, test_bkg, alternative='two-sided')
    
    return ks_sig, ks_bkg

# %%
def train_model(Xtrain_scaled, ytrain, Xvalid_scaled, yvalid, Xtest_scaled, ytest, n_estimators=200, eta=0.07, max_depth=3):

    # Used for the scale_pos_weight in the model
    ratio = np.count_nonzero(ytrain == 0) / np.count_nonzero(ytrain)

    
    model = xgb.XGBClassifier( eval_metric='logloss', 
                              n_estimators=n_estimators, 
                              eta=eta, 
                              #gamma=0.10,
                              #reg_lambda=4.34,
                              scale_pos_weight=ratio, 
                              max_depth=max_depth, 
                              random_state=42, tree_method="gpu_hist", verbosity=1, seed=42)

    
    # Now train
    evalset = [(Xtrain_scaled, ytrain), (Xvalid_scaled, yvalid)]
    res = model.fit(Xtrain_scaled, ytrain, eval_set=evalset, verbose=False)
    
    # Predict on test set 
    yscore = model.predict_proba(Xtest_scaled)
    fpr, tpr, _ = roc_curve(ytest, yscore[:,1])
    roc_auc = auc(fpr, tpr)
    
    # Measure overtraining
    kss, ksb = get_bdt_reponse_similarity(model, Xtrain_scaled, ytrain, Xtest_scaled, ytest)
    return roc_auc, kss, ksb

# %%
def cross_train_model(Xtrain_scaled, ytrain, Xvalid_scaled, yvalid, n_estimators=200, eta=0.03, max_depth=4):

    # Used for the scale_pos_weight in the model
    ratio = np.count_nonzero(ytrain == 0) / np.count_nonzero(ytrain)

    
    model = xgb.XGBClassifier( eval_metric='logloss', 
                              n_estimators=n_estimators, 
                              eta=eta, 
                              #gamma=0.10,
                              #reg_lambda=4.34,
                              scale_pos_weight=ratio, 
                              max_depth=max_depth, 
                              random_state=42, tree_method="gpu_hist", verbosity=1, seed=42)

    
    cvs = cross_validate(model, Xtrain_scaled, ytrain, cv=5, scoring='roc_auc', return_estimator=True)
    all_auc = []
    all_kss = []
    all_ksb = []
    
    for i, model in enumerate(cvs['estimator']):
        # Predict on test set 
        yscore = model.predict_proba(Xvalid_scaled)
        fpr, tpr, _ = roc_curve(yvalid, yscore[:,1])
        roc_auc = auc(fpr, tpr)        
            
        # Measure overtraining
        kss, ksb = get_bdt_reponse_similarity(model, Xtrain_scaled, ytrain, Xvalid_scaled, yvalid)
        all_auc.append(roc_auc)
        all_kss.append(kss)
        all_ksb.append(ksb)
    return all_auc, all_kss, all_ksb

# %%
def objective(trial):
    ratio = np.count_nonzero(ytrain == 0) / np.count_nonzero(ytrain)
    model = xgb.XGBClassifier(eval_metric='logloss', 
                              n_estimators=trial.suggest_int("n_estimators", 50, 100, step=50), 
                              eta=trial.suggest_float("eta", 0.01, 0.10, step=0.01), # 0.03, 
                              scale_pos_weight=ratio, 
                              max_depth=trial.suggest_int("max_depth", 3, 6), #4
                              gamma=0,#trial.suggest_float("gamma", 0, 0.2),
                              #reg_lambda=trial.suggest_float("lambda", 1.0, 10.0),
                              random_state=42, 
                              tree_method="gpu_hist",
                              verbosity=0)
    evalset = [(Xtrain_scaled, ytrain), (Xvalid_scaled, yvalid)]
    res = model.fit(Xtrain_scaled, ytrain, eval_set=evalset, verbose=False)
    yscore = model.predict_proba(Xvalid_scaled)
    fpr, tpr, _ = roc_curve(yvalid, yscore[:,1])
    roc_auc = auc(fpr, tpr)
    ks, kb = get_bdt_reponse_similarity(model, Xtrain_scaled, ytrain, Xtest_scaled, ytest)
    return (1 - roc_auc) * ks.statistic

# %%
# %time

study_name = "optuna-bdt-opt-nogamma"
study = optuna.create_study(direction="minimize", study_name=study_name, storage="sqlite:///{}.db".format(study_name), load_if_exists=True)
study.optimize(objective, n_trials=100)
print(study.best_trial)
# Out:
# [I 2023-09-11 23:25:17,503] Using an existing study with name 'optuna-bdt-opt-nogamma' instead of creating a new one.
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 12.4 µs
# [I 2023-09-11 23:25:18,312] Trial 204 finished with value: 0.004076060205486642 and parameters: {'n_estimators': 50, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:19,165] Trial 205 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:20,005] Trial 206 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:20,807] Trial 207 finished with value: 0.00535936460791221 and parameters: {'n_estimators': 50, 'eta': 0.04, 'max_depth': 5}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:21,646] Trial 208 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:22,495] Trial 209 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:23,343] Trial 210 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:24,189] Trial 211 finished with value: 0.0040700700277710965 and parameters: {'n_estimators': 100, 'eta': 0.03, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:25,009] Trial 212 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:25,833] Trial 213 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:26,662] Trial 214 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:27,492] Trial 215 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:28,324] Trial 216 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:29,173] Trial 217 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:30,004] Trial 218 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:30,838] Trial 219 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:31,679] Trial 220 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:32,514] Trial 221 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:33,388] Trial 222 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:34,243] Trial 223 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:35,119] Trial 224 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:35,951] Trial 225 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:36,796] Trial 226 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:37,637] Trial 227 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:38,451] Trial 228 finished with value: 0.0040700700277710965 and parameters: {'n_estimators': 100, 'eta': 0.03, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:39,286] Trial 229 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:40,133] Trial 230 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:40,976] Trial 231 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:41,804] Trial 232 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:42,647] Trial 233 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:43,523] Trial 234 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:44,367] Trial 235 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:45,228] Trial 236 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:46,076] Trial 237 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:46,964] Trial 238 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:48,123] Trial 239 finished with value: 0.008770806156631956 and parameters: {'n_estimators': 100, 'eta': 0.03, 'max_depth': 6}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:48,963] Trial 240 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:49,817] Trial 241 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:50,665] Trial 242 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:51,487] Trial 243 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:52,333] Trial 244 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:53,155] Trial 245 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:54,003] Trial 246 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:54,867] Trial 247 finished with value: 0.004160594280956382 and parameters: {'n_estimators': 100, 'eta': 0.09, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:55,717] Trial 248 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:56,582] Trial 249 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:57,453] Trial 250 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:58,292] Trial 251 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:25:59,143] Trial 252 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:00,012] Trial 253 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:00,941] Trial 254 finished with value: 0.004347801278852395 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 4}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:01,776] Trial 255 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:02,614] Trial 256 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:03,445] Trial 257 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:04,282] Trial 258 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:05,113] Trial 259 finished with value: 0.0040700700277710965 and parameters: {'n_estimators': 100, 'eta': 0.03, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:05,966] Trial 260 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:06,812] Trial 261 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:07,532] Trial 262 finished with value: 0.004076060205486642 and parameters: {'n_estimators': 50, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:08,380] Trial 263 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:09,212] Trial 264 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:10,062] Trial 265 finished with value: 0.0040700700277710965 and parameters: {'n_estimators': 100, 'eta': 0.03, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:10,905] Trial 266 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:11,761] Trial 267 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:12,611] Trial 268 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:13,487] Trial 269 finished with value: 0.004006976225765198 and parameters: {'n_estimators': 100, 'eta': 0.05, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:14,330] Trial 270 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:15,185] Trial 271 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:16,008] Trial 272 finished with value: 0.004006976225765198 and parameters: {'n_estimators': 100, 'eta': 0.05, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:16,843] Trial 273 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:17,689] Trial 274 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:18,543] Trial 275 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:19,403] Trial 276 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:20,267] Trial 277 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:21,114] Trial 278 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:21,936] Trial 279 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:22,781] Trial 280 finished with value: 0.0040700700277710965 and parameters: {'n_estimators': 100, 'eta': 0.03, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:23,611] Trial 281 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:24,471] Trial 282 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:25,316] Trial 283 finished with value: 0.004006976225765198 and parameters: {'n_estimators': 100, 'eta': 0.05, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:26,172] Trial 284 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:27,037] Trial 285 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:27,864] Trial 286 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:28,717] Trial 287 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:29,553] Trial 288 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:30,390] Trial 289 finished with value: 0.0040700700277710965 and parameters: {'n_estimators': 100, 'eta': 0.03, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:31,265] Trial 290 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:32,121] Trial 291 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:33,027] Trial 292 finished with value: 0.004662636776719907 and parameters: {'n_estimators': 100, 'eta': 0.05, 'max_depth': 4}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:33,874] Trial 293 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:34,725] Trial 294 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:35,554] Trial 295 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:36,382] Trial 296 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:37,248] Trial 297 finished with value: 0.0040700700277710965 and parameters: {'n_estimators': 100, 'eta': 0.03, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:38,101] Trial 298 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:39,106] Trial 299 finished with value: 0.006298101753959998 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 5}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:39,963] Trial 300 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:40,792] Trial 301 finished with value: 0.004650725522995463 and parameters: {'n_estimators': 100, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:41,506] Trial 302 finished with value: 0.004076060205486642 and parameters: {'n_estimators': 50, 'eta': 0.04, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# [I 2023-09-11 23:26:42,346] Trial 303 finished with value: 0.004006976225765198 and parameters: {'n_estimators': 100, 'eta': 0.05, 'max_depth': 3}. Best is trial 135 with value: 0.003762552131106066.
# FrozenTrial(number=135, state=TrialState.COMPLETE, values=[0.003762552131106066], datetime_start=datetime.datetime(2023, 9, 11, 23, 23, 42, 419237), datetime_complete=datetime.datetime(2023, 9, 11, 23, 23, 43, 343998), params={'n_estimators': 150, 'eta': 0.04, 'max_depth': 3}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_estimators': IntDistribution(high=150, log=False, low=50, step=50), 'eta': FloatDistribution(high=0.1, log=False, low=0.01, step=0.01), 'max_depth': IntDistribution(high=6, log=False, low=3, step=1)}, trial_id=136, value=None)

# %%
study.best_trial.params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 study.best_trial.params
#
# NameError: name 'study' is not defined

# %%
#params = study.best_trial.params
#params = {'n_estimators': 150, 'eta': 0.03, 'max_depth': 3}
params = {'n_estimators': 150, 'eta': 0.04, 'max_depth': 3}
ratio = np.count_nonzero(ytrain == 0) / np.count_nonzero(ytrain)
model = xgb.XGBClassifier( eval_metric='logloss', 
                          #n_estimators=120, 
                          #eta=0.10, 
                          #max_depth=3, 
                          scale_pos_weight=ratio, 
                          random_state=42, tree_method="hist", 
                          verbosity=1, **params)

# %%
# %%time
evalset = [(Xtrain_scaled, ytrain), (Xvalid_scaled, yvalid)]
res = model.fit(Xtrain_scaled, ytrain, eval_set=evalset, verbose=True)
# Out:
# [0]	validation_0-logloss:0.68377	validation_1-logloss:0.68370
# [1]	validation_0-logloss:0.67520	validation_1-logloss:0.67505
# [2]	validation_0-logloss:0.66733	validation_1-logloss:0.66712
# [3]	validation_0-logloss:0.65992	validation_1-logloss:0.65966
# [4]	validation_0-logloss:0.65300	validation_1-logloss:0.65267
# [5]	validation_0-logloss:0.64643	validation_1-logloss:0.64612
# [6]	validation_0-logloss:0.64021	validation_1-logloss:0.63988
# [7]	validation_0-logloss:0.63432	validation_1-logloss:0.63394
# [8]	validation_0-logloss:0.62883	validation_1-logloss:0.62846
# [9]	validation_0-logloss:0.62350	validation_1-logloss:0.62306
# [10]	validation_0-logloss:0.61807	validation_1-logloss:0.61760
# [11]	validation_0-logloss:0.61319	validation_1-logloss:0.61268
# [12]	validation_0-logloss:0.60846	validation_1-logloss:0.60796
# [13]	validation_0-logloss:0.60371	validation_1-logloss:0.60319
# [14]	validation_0-logloss:0.59956	validation_1-logloss:0.59897
# [15]	validation_0-logloss:0.59522	validation_1-logloss:0.59465
# [16]	validation_0-logloss:0.59123	validation_1-logloss:0.59068
# [17]	validation_0-logloss:0.58747	validation_1-logloss:0.58686
# [18]	validation_0-logloss:0.58363	validation_1-logloss:0.58304
# [19]	validation_0-logloss:0.57992	validation_1-logloss:0.57934
# [20]	validation_0-logloss:0.57633	validation_1-logloss:0.57570
# [21]	validation_0-logloss:0.57296	validation_1-logloss:0.57234
# [22]	validation_0-logloss:0.56959	validation_1-logloss:0.56899
# [23]	validation_0-logloss:0.56657	validation_1-logloss:0.56596
# [24]	validation_0-logloss:0.56326	validation_1-logloss:0.56262
# [25]	validation_0-logloss:0.56029	validation_1-logloss:0.55965
# [26]	validation_0-logloss:0.55741	validation_1-logloss:0.55674
# [27]	validation_0-logloss:0.55469	validation_1-logloss:0.55404
# [28]	validation_0-logloss:0.55214	validation_1-logloss:0.55149
# [29]	validation_0-logloss:0.54943	validation_1-logloss:0.54875
# [30]	validation_0-logloss:0.54692	validation_1-logloss:0.54625
# [31]	validation_0-logloss:0.54456	validation_1-logloss:0.54385
# [32]	validation_0-logloss:0.54192	validation_1-logloss:0.54119
# [33]	validation_0-logloss:0.53964	validation_1-logloss:0.53892
# [34]	validation_0-logloss:0.53730	validation_1-logloss:0.53659
# [35]	validation_0-logloss:0.53522	validation_1-logloss:0.53450
# [36]	validation_0-logloss:0.53320	validation_1-logloss:0.53247
# [37]	validation_0-logloss:0.53118	validation_1-logloss:0.53049
# [38]	validation_0-logloss:0.52896	validation_1-logloss:0.52826
# [39]	validation_0-logloss:0.52727	validation_1-logloss:0.52655
# [40]	validation_0-logloss:0.52538	validation_1-logloss:0.52467
# [41]	validation_0-logloss:0.52340	validation_1-logloss:0.52266
# [42]	validation_0-logloss:0.52162	validation_1-logloss:0.52088
# [43]	validation_0-logloss:0.51978	validation_1-logloss:0.51903
# [44]	validation_0-logloss:0.51797	validation_1-logloss:0.51725
# [45]	validation_0-logloss:0.51645	validation_1-logloss:0.51574
# [46]	validation_0-logloss:0.51496	validation_1-logloss:0.51424
# [47]	validation_0-logloss:0.51341	validation_1-logloss:0.51269
# [48]	validation_0-logloss:0.51158	validation_1-logloss:0.51084
# [49]	validation_0-logloss:0.51007	validation_1-logloss:0.50936
# [50]	validation_0-logloss:0.50862	validation_1-logloss:0.50790
# [51]	validation_0-logloss:0.50735	validation_1-logloss:0.50662
# [52]	validation_0-logloss:0.50576	validation_1-logloss:0.50502
# [53]	validation_0-logloss:0.50423	validation_1-logloss:0.50344
# [54]	validation_0-logloss:0.50282	validation_1-logloss:0.50205
# [55]	validation_0-logloss:0.50155	validation_1-logloss:0.50079
# [56]	validation_0-logloss:0.50013	validation_1-logloss:0.49937
# [57]	validation_0-logloss:0.49899	validation_1-logloss:0.49822
# [58]	validation_0-logloss:0.49778	validation_1-logloss:0.49696
# [59]	validation_0-logloss:0.49650	validation_1-logloss:0.49569
# [60]	validation_0-logloss:0.49519	validation_1-logloss:0.49435
# [61]	validation_0-logloss:0.49405	validation_1-logloss:0.49323
# [62]	validation_0-logloss:0.49309	validation_1-logloss:0.49225
# [63]	validation_0-logloss:0.49205	validation_1-logloss:0.49120
# [64]	validation_0-logloss:0.49088	validation_1-logloss:0.48998
# [65]	validation_0-logloss:0.48994	validation_1-logloss:0.48903
# [66]	validation_0-logloss:0.48874	validation_1-logloss:0.48782
# [67]	validation_0-logloss:0.48755	validation_1-logloss:0.48662
# [68]	validation_0-logloss:0.48653	validation_1-logloss:0.48561
# [69]	validation_0-logloss:0.48543	validation_1-logloss:0.48448
# [70]	validation_0-logloss:0.48452	validation_1-logloss:0.48357
# [71]	validation_0-logloss:0.48369	validation_1-logloss:0.48272
# [72]	validation_0-logloss:0.48260	validation_1-logloss:0.48159
# [73]	validation_0-logloss:0.48169	validation_1-logloss:0.48069
# [74]	validation_0-logloss:0.48089	validation_1-logloss:0.47989
# [75]	validation_0-logloss:0.48015	validation_1-logloss:0.47913
# [76]	validation_0-logloss:0.47925	validation_1-logloss:0.47822
# [77]	validation_0-logloss:0.47854	validation_1-logloss:0.47750
# [78]	validation_0-logloss:0.47759	validation_1-logloss:0.47655
# [79]	validation_0-logloss:0.47667	validation_1-logloss:0.47565
# [80]	validation_0-logloss:0.47586	validation_1-logloss:0.47483
# [81]	validation_0-logloss:0.47519	validation_1-logloss:0.47414
# [82]	validation_0-logloss:0.47442	validation_1-logloss:0.47335
# [83]	validation_0-logloss:0.47370	validation_1-logloss:0.47264
# [84]	validation_0-logloss:0.47296	validation_1-logloss:0.47187
# [85]	validation_0-logloss:0.47227	validation_1-logloss:0.47116
# [86]	validation_0-logloss:0.47146	validation_1-logloss:0.47032
# [87]	validation_0-logloss:0.47092	validation_1-logloss:0.46979
# [88]	validation_0-logloss:0.47019	validation_1-logloss:0.46907
# [89]	validation_0-logloss:0.46962	validation_1-logloss:0.46852
# [90]	validation_0-logloss:0.46887	validation_1-logloss:0.46774
# [91]	validation_0-logloss:0.46831	validation_1-logloss:0.46719
# [92]	validation_0-logloss:0.46769	validation_1-logloss:0.46658
# [93]	validation_0-logloss:0.46712	validation_1-logloss:0.46601
# [94]	validation_0-logloss:0.46653	validation_1-logloss:0.46539
# [95]	validation_0-logloss:0.46576	validation_1-logloss:0.46459
# [96]	validation_0-logloss:0.46513	validation_1-logloss:0.46394
# [97]	validation_0-logloss:0.46453	validation_1-logloss:0.46334
# [98]	validation_0-logloss:0.46397	validation_1-logloss:0.46278
# [99]	validation_0-logloss:0.46334	validation_1-logloss:0.46218
# [100]	validation_0-logloss:0.46265	validation_1-logloss:0.46147
# [101]	validation_0-logloss:0.46213	validation_1-logloss:0.46098
# [102]	validation_0-logloss:0.46157	validation_1-logloss:0.46042
# [103]	validation_0-logloss:0.46090	validation_1-logloss:0.45971
# [104]	validation_0-logloss:0.46046	validation_1-logloss:0.45927
# [105]	validation_0-logloss:0.46004	validation_1-logloss:0.45884
# [106]	validation_0-logloss:0.45952	validation_1-logloss:0.45833
# [107]	validation_0-logloss:0.45902	validation_1-logloss:0.45781
# [108]	validation_0-logloss:0.45856	validation_1-logloss:0.45735
# [109]	validation_0-logloss:0.45810	validation_1-logloss:0.45690
# [110]	validation_0-logloss:0.45745	validation_1-logloss:0.45626
# [111]	validation_0-logloss:0.45677	validation_1-logloss:0.45559
# [112]	validation_0-logloss:0.45625	validation_1-logloss:0.45508
# [113]	validation_0-logloss:0.45585	validation_1-logloss:0.45466
# [114]	validation_0-logloss:0.45543	validation_1-logloss:0.45424
# [115]	validation_0-logloss:0.45479	validation_1-logloss:0.45361
# [116]	validation_0-logloss:0.45438	validation_1-logloss:0.45319
# [117]	validation_0-logloss:0.45392	validation_1-logloss:0.45271
# [118]	validation_0-logloss:0.45340	validation_1-logloss:0.45216
# [119]	validation_0-logloss:0.45287	validation_1-logloss:0.45163
# [120]	validation_0-logloss:0.45243	validation_1-logloss:0.45120
# [121]	validation_0-logloss:0.45212	validation_1-logloss:0.45089
# [122]	validation_0-logloss:0.45159	validation_1-logloss:0.45038
# [123]	validation_0-logloss:0.45110	validation_1-logloss:0.44989
# [124]	validation_0-logloss:0.45062	validation_1-logloss:0.44943
# [125]	validation_0-logloss:0.45031	validation_1-logloss:0.44911
# [126]	validation_0-logloss:0.44994	validation_1-logloss:0.44873
# [127]	validation_0-logloss:0.44952	validation_1-logloss:0.44833
# [128]	validation_0-logloss:0.44916	validation_1-logloss:0.44797
# [129]	validation_0-logloss:0.44870	validation_1-logloss:0.44751
# [130]	validation_0-logloss:0.44810	validation_1-logloss:0.44691
# [131]	validation_0-logloss:0.44768	validation_1-logloss:0.44650
# [132]	validation_0-logloss:0.44727	validation_1-logloss:0.44609
# [133]	validation_0-logloss:0.44693	validation_1-logloss:0.44574
# [134]	validation_0-logloss:0.44649	validation_1-logloss:0.44529
# [135]	validation_0-logloss:0.44591	validation_1-logloss:0.44472
# [136]	validation_0-logloss:0.44556	validation_1-logloss:0.44438
# [137]	validation_0-logloss:0.44529	validation_1-logloss:0.44411
# [138]	validation_0-logloss:0.44484	validation_1-logloss:0.44363
# [139]	validation_0-logloss:0.44421	validation_1-logloss:0.44303
# [140]	validation_0-logloss:0.44383	validation_1-logloss:0.44265
# [141]	validation_0-logloss:0.44333	validation_1-logloss:0.44216
# [142]	validation_0-logloss:0.44295	validation_1-logloss:0.44178
# [143]	validation_0-logloss:0.44261	validation_1-logloss:0.44143
# [144]	validation_0-logloss:0.44231	validation_1-logloss:0.44114
# [145]	validation_0-logloss:0.44198	validation_1-logloss:0.44080
# [146]	validation_0-logloss:0.44158	validation_1-logloss:0.44038
# [147]	validation_0-logloss:0.44107	validation_1-logloss:0.43987
# [148]	validation_0-logloss:0.44078	validation_1-logloss:0.43959
# [149]	validation_0-logloss:0.44004	validation_1-logloss:0.43889
# CPU times: user 59.7 s, sys: 171 ms, total: 59.9 s
# Wall time: 7.98 s

# %%
plt.rcParams.update({'font.size': 14})
results = model.evals_result()
# plot learning curves
plt.plot(results['validation_0']['logloss'], label='train')
plt.plot(results['validation_1']['logloss'], label='test')
# show the legend
plt.legend(fontsize=14)
# show the plotabs
plt.ylabel("logloss")
plt.xlabel("training iteration")
plt.tight_layout()
plt.savefig("doublecharmbdt_training.png")

# %%
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import roc_curve, auc
yscore = model.predict_proba(Xtest_scaled)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(25, 8))

# ROC curve 
#RocCurveDisplay.from_estimator(classifier, Xtest, ytest).plot(ax=ax2)
fpr, tpr, _ = roc_curve(ytest, yscore[:,1])
roc_auc = auc(fpr, tpr)
ax2.plot(1 - fpr, tpr)
ax2.set_title(f" True Pos rate  vs (1 - false pros rate) (AUC:{roc_auc})")
print(roc_auc)

# Classifier output
ax1.set_title(f"XGBoost Classifier output")
t = 'step'
n, bins, p = ax1.hist(yscore[ytest == 1, 1], bins=60, histtype=t, label='signal', density=True);
ax1.hist(yscore[ytest == 0, 1], bins=len(bins)-1, histtype=t, label='background', density=True);
ax1.legend();
plt.tight_layout()
plt.savefig("bdtdoublecharm_output.png")
# Out:
# 0.8778216821401145

# %%
plt.rcParams.update({'font.size': 14})
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import roc_curve, auc
yscore = model.predict_proba(Xtest_scaled)



fpr, tpr, _ = roc_curve(ytest, yscore[:,1])
roc_auc = auc(fpr, tpr)
plt.plot(1 - fpr, tpr)
plt.title(f" True positive rate  vs (1 - false positive rate) (AUC:{roc_auc:.3})")
print(roc_auc)
ax1.legend();
plt.tight_layout()
plt.savefig("bdtdoublecharm_roc.png")
# Out:
# 0.8778216821401145

# %%
plt.rcParams.update({'font.size': 14})
plt.title(f"XGBoost Classifier output")
t = 'step'
n, bins, p = plt.hist(yscore[ytest == 1, 1], bins=60, histtype=t, label='signal', density=True);
plt.hist(yscore[ytest == 0, 1], bins=len(bins)-1, histtype=t, label='background', density=True);
plt.legend(loc="upper center");
plt.tight_layout()
plt.savefig("bdtdoublecharm_output.png")

# %%
plt.rcParams.update({'font.size': 10})
plt.barh(train_columns, model.feature_importances_);
plt.tight_layout()
plt.savefig("bdtdoublecharm_features_importance.png")

# %%
plt.rcParams.update({'font.size': 14})
def compare_train_test(clf, X_train, y_train, X_test, y_test, bins=100):
    ''' Taken from Tim Head's recipe: https://betatim.github.io/posts/sklearn-for-TMVA-users/ '''
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    decisions = []
    for X,y in ((X_train, y_train), (X_test, y_test)):
        d1 = clf.predict_proba(X[y==1])[:,1]
        d2 = clf.predict_proba(X[y==0])[:,1]
        decisions += [d1, d2]
        
    print(len(decisions))
        
    low = min(np.min(d) for d in decisions)
    high = max(np.max(d) for d in decisions)
    low_high = (low,high)
    
    ax1.hist(decisions[0],
             color='r', alpha=0.5, range=low_high, bins=bins,
             histtype='stepfilled', density=True,
             label='Signal (training sample)')
    ax2.hist(decisions[1],
             color='b', alpha=0.5, range=low_high, bins=bins,
             histtype='stepfilled', density=True,
             label='Background (training sample)')

    
    hist, bins = np.histogram(decisions[2],
                              bins=bins, range=low_high, density=True)
    scale = len(decisions[2]) / sum(hist)
    err = np.sqrt(hist * scale) / scale
    
    width = (bins[1] - bins[0])
    center = (bins[:-1] + bins[1:]) / 2
    ax1.errorbar(center, hist, yerr=err, fmt='o', c='r', label='Signal (test sample)')
    
    hist, bins = np.histogram(decisions[3],
                              bins=bins, range=low_high, density=True)

    scale = len(decisions[3]) / sum(hist)
    
    err = np.sqrt(hist * scale) / scale

    ax2.errorbar(center, hist, yerr=err, fmt='o', c='b', label='Background (test sample)')

    ax1.set_xlabel("BDT output")
    ax1.set_ylabel("Arbitrary units")
    ax1.legend(loc='upper left')

    ax2.set_xlabel("BDT output")
    ax2.set_ylabel("Arbitrary units")
    ax2.legend(loc='best')
    plt.tight_layout()
    plt.savefig("bdtdoublecharm_overfitting_check.png")

    
compare_train_test(model, Xtrain_scaled, ytrain, Xtest_scaled, ytest)
# Out:
# 4
