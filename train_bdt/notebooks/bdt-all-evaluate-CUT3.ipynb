# %% [markdown]
# # Similarities between the templates for CUT3 (bdt_all > 0.5)

# %% [markdown]
# ### Setting up the data and tools

# %%
# Importing the notebook with common setup 
# %run 'bdt-all-common.ipynb'
# Out:
# Welcome to JupyROOT 6.28/00
# <style>.container { width:95% !important; }</style>
# Invoke (root_datasets, pandas_datasets) = load_data(inclmc_type="23903000") to load datasets
# Invoke (root_datasets, pandas_datasets) = load_data(inclmc_type="23903003") to load dataset for double charm
# Invoke  df_signal_23903000 = load_signal_from_inclMC() to load signal from 23903000 Inclusive MC
# or
# Invoke  df_signal = load_signal_all()
# Invoke  df_background = load_background_category(category)

# %%
import seaborn as sn
plt.rcParams["figure.figsize"] = (15,4)

# %% [markdown]
# ## Applying  CUT3 i.e. BDT_all > 0.5

# %%
bdt_cutval=0.5

# %%
dfcut = df.query(f"bdt_all > {bdt_cutval}")
c = mygroupby(dfcut, 'category')
c['name'] = c.apply(lambda row: categories[f"{row['category']:.4g}"], axis=1)
c
# Out:
#     category  count  Percentage  cumulative %  \
# 0         19  13643   24.699024     24.699024
# 1         18   5634   10.199685     34.898709
# 2         14   5470    9.902783     44.801492
# 3         22   5059    9.158716     53.960208
# 4         24   4940    8.943281     62.903489
# 5         20   4845    8.771295     71.674783
# 6          0   4794    8.678965     80.353748
# 7          7   2544    4.605609     84.959357
# 8         23   2430    4.399225     89.358582
# 9         25   1127    2.040299     91.398881
# 10        16    747    1.352354     92.751236
# 11        21    701    1.269077     94.020312
# 12        26    605    1.095280     95.115593
# 13        29    543    0.983037     96.098630
# 14        13    472    0.854500     96.953129
# 15        27    375    0.678893     97.632022
# 16        15    280    0.506907     98.138929
# 17        28    169    0.305954     98.444883
# 18         8    160    0.289661     98.734544
# 19         2    153    0.276988     99.011532
# 20         6    130    0.235349     99.246882
# 21        31     80    0.144830     99.391712
# 22        30     72    0.130347     99.522059
# 23        17     64    0.115864     99.637924
# 24        35     52    0.094140     99.732064
# 25         1     33    0.059743     99.791806
# 26        37     19    0.034397     99.826203
# 27        10     14    0.025345     99.851549
# 28         3     13    0.023535     99.875084
# 29        39     10    0.018104     99.893188
# 30        -1      9    0.016293     99.909481
# 31        32      8    0.014483     99.923964
# 32        12      7    0.012673     99.936637
# 33        36      7    0.012673     99.949309
# 34        44      6    0.010862     99.960172
# 35        41      5    0.009052     99.969224
# 36         4      4    0.007242     99.976465
# 37        45      4    0.007242     99.983707
# 38        33      3    0.005431     99.989138
# 39        11      3    0.005431     99.994569
# 40         9      2    0.003621     99.998190
# 41        34      1    0.001810    100.000000
#
#                                                  name
# 0              Xc_signal_Ypis_displaced_fromB0_fromDp
# 1              Xc_signal_Ypis_displaced_fromBs_fromDs
# 2      Xc_signal_Ypis_diffVertex_doubleCharm_OneFromB
# 3              Xc_signal_Ypis_displaced_fromBs_fromDp
# 4             Xc_signal_Ypis_displaced_fromBs_fromTau
# 5              Xc_signal_Ypis_displaced_fromBp_fromD0
# 6                                       Xc_background
# 7                  Xc_signal_Ypis_nomatch_doubleCharm
# 8              Xc_signal_Ypis_displaced_fromBp_fromDp
# 9              Xc_signal_Ypis_displaced_fromB0_fromD0
# 10             Xc_signal_Ypis_diffVertex_CharmStrange
# 11   Xc_signal_Ypis_displaced_fromLambdab_fromLambdac
# 12             Xc_signal_Ypis_displaced_fromB0_fromDs
# 13     Xc_signal_Ypis_displaced_fromBs_fromDs_fromTau
# 14              Xc_signal_Ypis_diffVertex_doubleCharm
# 15             Xc_signal_Ypis_displaced_fromBs_fromD0
# 16     Xc_signal_Ypis_diffVertex_doubleCharm_TwoFromB
# 17             Xc_signal_Ypis_displaced_fromBp_fromDs
# 18                Xc_signal_Ypis_nomatch_charmStrange
# 19                     Xc_signal_Ypis_B_vertex_fromBs
# 20                      Xc_signal_Ypis_nomatch_Prompt
# 21        Xc_signal_Ypis_displaced_fromLambdab_fromDp
# 22        Xc_signal_Ypis_displaced_fromLambdab_fromDs
# 23               Xc_signal_Ypis_diffVertex_SomeFromPV
# 24     Xc_signal_Ypis_displaced_fromB0_fromDs_fromTau
# 25                     Xc_signal_Ypis_diffAncestorYXc
# 26     Xc_signal_Ypis_displaced_fromB0_fromDp_fromTau
# 27                   Xc_signal_Ypis_diffVertex_signal
# 28                 Xc_signal_Ypis_B_vertex_fromOtherB
# 29     Xc_signal_Ypis_displaced_fromBp_fromDs_fromTau
# 30                                                 NA
# 31                   Xc_signal_Ypis_displaced_fromXic
# 32                 Xc_signal_Ypis_diffVertex_normlike
# 33        Xc_signal_Ypis_displaced_fromLambdab_fromD0
# 34     Xc_signal_Ypis_displaced_fromBs_fromDp_fromTau
# 35  Xc_signal_Ypis_displaced_fromLambdab_fromDs_fr...
# 36                     Xc_signal_Ypis_B_vertex_fromHc
# 37     Xc_signal_Ypis_displaced_fromBp_fromDp_fromTau
# 38                    Xc_signal_Ypis_displaced_fromBs
# 39                 Xc_signal_Ypis_diffVertex_tauFromB
# 40                       Xc_signal_Ypis_nomatch_Other
# 41        Xc_signal_Ypis_displaced_fromB0_fromLambdac

# %% [markdown]
# There are 17 categories that are bigger than by more than around 0.5% of the total

# %% [markdown]
# ## Using Kolmogorov-Smirnov test to see which distributions are similar

# %%
shown_number=17
sq2_2, stauY_2, sbdt_all = similar_categories(dfcut, shown_number)

# %%
# Prepare some data to display histogramsand add to display tools
shown_categs = list(c.head(shown_number)['category'])
datasets = { f"{c}":  dfcut.query(f"category == {c}") for c in shown_categs }
datasets["others"] =  dfcut.query(f"category not in {shown_categs}")
datasets_names = { f"{c}": f"{c}:" + categories[f"{c}"] for c in shown_categs}
datasets_names["others"] = "others"

def plot_templates(datasets, datasets_names, myvar):
    htype = 'stepfilled'
    a = 0.30
    plt.hist([ d[myvar] for d in datasets ], bins=40, label=datasets_names, density=True, histtype=htype, alpha=a)
#     if myvar == "tauY_2":
#         plt.xlim([0, 0.004])
    plt.title(myvar)
    plt.legend()

def plot_templates_categs(mycategs, myvar):
    plot_templates([ datasets[d] for d in mycategs ], [ datasets_names[d] for d in mycategs ], myvar)

# %% [markdown]
# ## Checking q2_2 distributions

# %%
plt.figure()
sn.heatmap(sq2_2)
plt.title("Similarity of q2_2 distributions for the categories");

# %%
from pprint import pprint
clusters = find_and_merge_clusters(sq2_2, 0.1)
pprint(clusters)

# %%
plt.rcParams["figure.figsize"] = (15,4)
for c in clusters:
    plt.figure()
    plot_templates_categs(c, 'q2_2')

# %% [markdown]
# ## Checking tauY_2 distributions

# %%
plt.figure()
sn.heatmap(stauY_2)
plt.title("Similarity of tauY_2 distributions for the categories");

# %%
from pprint import pprint
clusters = find_and_merge_clusters(stauY_2, 0.1)
pprint(clusters)

# %%
for c in clusters:
    plt.figure()
    plot_templates_categs(c, 'tauY_2')

# %% [markdown]
# ## Checking bdt_all distributions

# %%
plt.figure()
sn.heatmap(sbdt_all)
plt.title("Similarity of bdt_all distributions for the categories");

# %%
from pprint import pprint
clusters = find_and_merge_clusters(sbdt_all, 0.1)
pprint(clusters)

# %%
for c in clusters:
    plt.figure()
    plot_templates_categs(c, 'bdt_all')
