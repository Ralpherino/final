# %% [markdown]
# ## Calling workflow to create file with data if needed

# %%
rs_cache = "rds_fitcandidates_2012_23903000_rs.pickle"
ws_cache = "rds_fitcandidates_2012_23903000_ws.pickle"

# %%
# !cd .. && snakemake -c 1 {rs_cache} {ws_cache}
# Out:
# Building DAG of jobs...
# Nothing to be done (all requested files are present and up to date).
# Complete log: .snakemake/log/2023-10-25T102026.696505.snakemake.log

# %% [markdown]
# ## Loading the files themselves

# %%
import pandas as pd
from pathlib import Path

# %%
df_rs = pd.read_pickle(Path("..") / rs_cache)
df_ws = pd.read_pickle(Path("..") / ws_cache)

# %%
print("df_rs and df_ws are now available with the right sign and wrong sign data")
# Out:
# df_rs and df_ws are now available with the right sign and wrong sign data
